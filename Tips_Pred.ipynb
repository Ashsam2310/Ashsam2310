# %% [markdown]
# <a href="https://colab.research.google.com/github/Ashsam2310/Ashsam2310/blob/main/Tips_Pred.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# %%
#read the excel file into a dataframe
df=pd.read_excel('/content/Case Waiter Tips.xlsx',header=[1])

# %%
df
# Out:
#      Unnamed: 0  Total Bill in INR  Tip to the Waiter     Sex Smoker   Day  \
# 0           NaN            1274.25              75.75  Female     No   Sun
# 1           NaN             775.50             124.50    Male     No   Sun
# 2           NaN            1575.75             262.50    Male     No   Sun
# 3           NaN            1776.00             248.25    Male     No   Sun
# 4           NaN            1844.25             270.75  Female     No   Sun
# ..          ...                ...                ...     ...    ...   ...
# 239         NaN            2177.25             444.00    Male     No   Sat
# 240         NaN            2038.50             150.00  Female    Yes   Sat
# 241         NaN            1700.25             150.00    Male    Yes   Sat
# 242         NaN            1336.50             131.25    Male     No   Sat
# 243         NaN            1408.50             225.00  Female     No  Thur
#
#     Meal Type  Number of people in a table
# ...

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter     Sex Smoker   Day Meal Type  \
# 0              1274.25              75.75  Female     No   Sun    Dinner
# 1               775.50             124.50    Male     No   Sun    Dinner
# 2              1575.75             262.50    Male     No   Sun    Dinner
# 3              1776.00             248.25    Male     No   Sun    Dinner
# 4              1844.25             270.75  Female     No   Sun    Dinner
# ..                 ...                ...     ...    ...   ...       ...
# 239            2177.25             444.00    Male     No   Sat    Dinner
# 240            2038.50             150.00  Female    Yes   Sat    Dinner
# 241            1700.25             150.00    Male    Yes   Sat    Dinner
# 242            1336.50             131.25    Male     No   Sat    Dinner
# 243            1408.50             225.00  Female     No  Thur    Dinner
#
#      Number of people in a table
# 0                              2
# ...

# %%
df.shape
# Out:
# (244, 7)

# %%
df.drop('Unnamed: 0',axis=1,inplace=True)

# %%
df.describe()
# Out:
#        Total Bill in INR  Tip to the Waiter  Number of people in a table
# count         244.000000         244.000000                   244.000000
# mean         1483.945697         224.870902                     2.569672
# std           667.680897         103.772864                     0.951100
# min           230.250000          75.000000                     1.000000
# 25%          1001.062500         150.000000                     2.000000
# 50%          1334.625000         217.500000                     2.000000
# 75%          1809.562500         267.187500                     3.000000
# max          3810.750000         750.000000                     6.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Total Bill in INR            244 non-null    float64
#  1   Tip to the Waiter            244 non-null    float64
#  2   Sex                          244 non-null    int64
#  3   Smoker                       244 non-null    int64
#  4   Day                          244 non-null    int64
#  5   Meal Type                    244 non-null    int64
#  6   Number of people in a table  244 non-null    int64
# dtypes: float64(2), int64(5)
# memory usage: 13.5 KB

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 244 entries, 0 to 243
# Data columns (total 7 columns):
#  #   Column                       Non-Null Count  Dtype
# ---  ------                       --------------  -----
#  0   Total Bill in INR            244 non-null    float64
#  1   Tip to the Waiter            244 non-null    float64
#  2   Sex                          244 non-null    object
#  3   Smoker                       244 non-null    object
#  4   Day                          244 non-null    object
#  5   Meal Type                    244 non-null    object
#  6   Number of people in a table  244 non-null    int64
# dtypes: float64(2), int64(1), object(4)
# memory usage: 13.5+ KB

# %%
df['Sex'].unique()
# Out:
# array([1, 0])

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter     Sex Smoker   Day Meal Type  \
# 0              1274.25              75.75  Female     No   Sun    Dinner
# 1               775.50             124.50    Male     No   Sun    Dinner
# 2              1575.75             262.50    Male     No   Sun    Dinner
# 3              1776.00             248.25    Male     No   Sun    Dinner
# 4              1844.25             270.75  Female     No   Sun    Dinner
# ..                 ...                ...     ...    ...   ...       ...
# 239            2177.25             444.00    Male     No   Sat    Dinner
# 240            2038.50             150.00  Female    Yes   Sat    Dinner
# 241            1700.25             150.00    Male    Yes   Sat    Dinner
# 242            1336.50             131.25    Male     No   Sat    Dinner
# 243            1408.50             225.00  Female     No  Thur    Dinner
#
#      Number of people in a table
# 0                              2
# ...

# %%
# transforming the categorical values into numerical values:
        # if "all"categorical features
#df['Sex'] = df['Sex'].map({'Female':1,'Male':0})
df['smoker'] = df['smoker'].map({'No':1,'Yes':0})
df['day'] = df['day'].map({'Sun':1, 'Sat':2,'Thur':3, 'Fri':4})
df['time'] = df['time'].map({'Dinner':1,'Lunch':0})
df

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter     Sex  Smoker   Day Meal Type  \
# 0              1274.25              75.75  Female       1   Sun    Dinner
# 1               775.50             124.50    Male       1   Sun    Dinner
# 2              1575.75             262.50    Male       1   Sun    Dinner
# 3              1776.00             248.25    Male       1   Sun    Dinner
# 4              1844.25             270.75  Female       1   Sun    Dinner
# ..                 ...                ...     ...     ...   ...       ...
# 239            2177.25             444.00    Male       1   Sat    Dinner
# 240            2038.50             150.00  Female       0   Sat    Dinner
# 241            1700.25             150.00    Male       0   Sat    Dinner
# 242            1336.50             131.25    Male       1   Sat    Dinner
# 243            1408.50             225.00  Female       1  Thur    Dinner
#
#      Number of people in a table
# 0                              2
# ...

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter     Sex Smoker   Day Meal Type  \
# 0              1274.25              75.75  Female     No   Sun    Dinner
# 1               775.50             124.50    Male     No   Sun    Dinner
# 2              1575.75             262.50    Male     No   Sun    Dinner
# 3              1776.00             248.25    Male     No   Sun    Dinner
# 4              1844.25             270.75  Female     No   Sun    Dinner
# ..                 ...                ...     ...    ...   ...       ...
# 239            2177.25             444.00    Male     No   Sat    Dinner
# 240            2038.50             150.00  Female    Yes   Sat    Dinner
# 241            1700.25             150.00    Male    Yes   Sat    Dinner
# 242            1336.50             131.25    Male     No   Sat    Dinner
# 243            1408.50             225.00  Female     No  Thur    Dinner
#
#      Number of people in a table
# 0                              2
# ...

# %%
df['Smoker'] = df['Smoker'].map({'No':1,'Yes':0})

# %%
df['Day'] = df['Day'].map({'Sun':1,'Sat':2,'Thur':3,'Fri':4})

# %%
df["Sex"] = df["Sex"].replace({'Female':1,'Male':0})

# %%
df["Meal Type"] = df["Meal Type"].replace({'Dinner':1,'Lunch':0})

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter  Sex  Smoker  Day  Meal Type  \
# 0              1274.25              75.75    1       1    1          1
# 1               775.50             124.50    0       1    1          1
# 2              1575.75             262.50    0       1    1          1
# 3              1776.00             248.25    0       1    1          1
# 4              1844.25             270.75    1       1    1          1
# ..                 ...                ...  ...     ...  ...        ...
# 239            2177.25             444.00    0       1    2          1
# 240            2038.50             150.00    1       0    2          1
# 241            1700.25             150.00    0       0    2          1
# 242            1336.50             131.25    0       1    2          1
# 243            1408.50             225.00    1       1    3          1
#
#      Number of people in a table
# 0                              2
# 1                              3
# ...

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter  Sex  Smoker  Day Meal Type  \
# 0              1274.25              75.75    1       1    1    Dinner
# 1               775.50             124.50    0       1    1    Dinner
# 2              1575.75             262.50    0       1    1    Dinner
# 3              1776.00             248.25    0       1    1    Dinner
# 4              1844.25             270.75    1       1    1    Dinner
# ..                 ...                ...  ...     ...  ...       ...
# 239            2177.25             444.00    0       1    2    Dinner
# 240            2038.50             150.00    1       0    2    Dinner
# 241            1700.25             150.00    0       0    2    Dinner
# 242            1336.50             131.25    0       1    2    Dinner
# 243            1408.50             225.00    1       1    3    Dinner
#
#      Number of people in a table
# 0                              2
# 1                              3
# ...

# %%
sns.barplot(x='Total Bill in INR',y='Day',data=df)

# %%
sns.barplot(y='Day',x='Tip to the Waiter',palette='muted',data=df)

# %%
sns.countplot('Sex',hue='Day',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.countplot('Sex',hue='Day',data=df)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning:
#
# Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.

# %%
sns.barplot(y='Sex',x='Day',data=df)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-84-3a1c69e91ce4> in <module>()
# ----> 1 sns.barplot(y='Sex',x='Day',data=df)
#
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# /usr/local/lib/python3.7/dist-packages/seaborn/categorical.py in barplot(x, y, hue, data, order, hue_order, estimator, ci, n_boot, units, seed, orient, color, palette, saturation, errcolor, errwidth, capsize, dodge, ax, **kwargs)
#    3183                           estimator, ci, n_boot, units, seed,
#    3184                           orient, color, palette, saturation,
# -> 3185                           errcolor, errwidth, capsize, dodge)
#    3186
# ...

# %%
sns.barplot(x='Number of people in a table',y='Tip to the Waiter',palette='muted',data=df)

# %%
sns.barplot(x='Meal Type',y='Tip to the Waiter',hue='Number of people in a table',palette='muted',data=df)

# %%
import plotly.express as px
fig4 = px.pie(df,
             values='Tip to the Waiter',
             names='Day',
             hole=0.5 # hole as a percentage of whole
             )
fig4
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
fig5 = px.pie(df,
             values='Tip to the Waiter',
             names='Smoker'
             )
fig5
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
df
# Out:
#      Total Bill in INR  Tip to the Waiter  Sex  Smoker  Day  Meal Type  \
# 0              1274.25              75.75    1       1    1          1
# 1               775.50             124.50    0       1    1          1
# 2              1575.75             262.50    0       1    1          1
# 3              1776.00             248.25    0       1    1          1
# 4              1844.25             270.75    1       1    1          1
# ..                 ...                ...  ...     ...  ...        ...
# 239            2177.25             444.00    0       1    2          1
# 240            2038.50             150.00    1       0    2          1
# 241            1700.25             150.00    0       0    2          1
# 242            1336.50             131.25    0       1    2          1
# 243            1408.50             225.00    1       1    3          1
#
#      Number of people in a table
# 0                              2
# 1                              3
# ...

# %%
X = df.drop('Tip to the Waiter',axis=1) 
X
# Out:
#      Total Bill in INR  Sex  Smoker  Day  Meal Type  \
# 0              1274.25    1       1    1          1
# 1               775.50    0       1    1          1
# 2              1575.75    0       1    1          1
# 3              1776.00    0       1    1          1
# 4              1844.25    1       1    1          1
# ..                 ...  ...     ...  ...        ...
# 239            2177.25    0       1    2          1
# 240            2038.50    1       0    2          1
# 241            1700.25    0       0    2          1
# 242            1336.50    0       1    2          1
# 243            1408.50    1       1    3          1
#
#      Number of people in a table
# 0                              2
# 1                              3
# 2                              3
# 3                              2
# 4                              4
# ..                           ...
# 239                            3
# 240                            2
# ...

# %%
Y=df['Tip to the Waiter']

# %%
from sklearn.model_selection import train_test_split
X_train,X_test,Y_train,Y_test = train_test_split(X,Y,
                                                 test_size=0.25, #20% is reserved for "testing of TRAINING dataset"
                                                 random_state=75)

# %%
from sklearn.linear_model import LinearRegression
LG = LinearRegression()
LG.fit(X_train,Y_train)
# Out:
# LinearRegression()

# %%
LG.score(X_test,Y_test)
# Out:
# 0.4988390907989987

# %%
LG.score(X_train,Y_train)
# Out:
# 0.45974573594656565

# %%
a=X_test.head()

# %%
a
# Out:
#      Total Bill in INR  Sex  Smoker  Day  Meal Type  \
# 208            1820.25    0       0    2          1
# 125            2235.00    1       1    3          0
# 91             1686.75    0       1    4          1
# 40             1203.00    0       1    2          1
# 66             1233.75    1       1    2          1
#
#      Number of people in a table
# 208                            2
# 125                            6
# 91                             2
# 40                             3
# 66                             2

# %%
Y_test.head()
# Out:
# 208    152.25
# 125    315.00
# 91     262.50
# 40     168.00
# 66     185.25
# Name: Tip to the Waiter, dtype: float64

# %%
LG.predict(a)
# Out:
# array([245.44567198, 354.49103112, 239.04306948, 208.89673093,
#        194.15754525])
